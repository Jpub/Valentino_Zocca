# %%
import random
from collections import deque

# 텐서플로우를 반드시 gym 라이브러리를 불러오기전에 불러와야한다. 
import tensorflow as tf
import gym
import numpy as np

env = gym.make('CartPole-v0')

ACTIONS_COUNT = 2
FUTURE_REWARD_DISCOUNT = 0.9
OBSERVATION_STEPS = 5000  # 훈련 이전에 관찰을 위한 시간 단위 
EXPLORE_STEPS = 15000
INITIAL_RANDOM_ACTION_PROB = 1.0  # 무작위의 액션 중 처음 시작할 액션 
FINAL_RANDOM_ACTION_PROB = 0.0  # 무작위의 액션 중 최종 선택된 것 
MEMORY_SIZE = 20000  # 기록할 관찰 횟수 
MINI_BATCH_SIZE = 100  # 미니배치 크기 
OBS_LAST_STATE_INDEX, OBS_ACTION_INDEX, OBS_REWARD_INDEX, OBS_CURRENT_STATE_INDEX, OBS_TERMINAL_INDEX = range(5)
LEARN_RATE = 1e-3
STORE_SCORES_LEN = 100
INPUT_NODES = env.observation_space.shape[0]
HIDDEN_NODES = 20

session = tf.Session()

feed_forward_weights_1 = tf.Variable(tf.truncated_normal([INPUT_NODES, HIDDEN_NODES], stddev=0.01))
feed_forward_bias_1 = tf.Variable(tf.constant(0.0, shape=[HIDDEN_NODES]))

feed_forward_weights_2 = tf.Variable(tf.truncated_normal([HIDDEN_NODES, ACTIONS_COUNT], stddev=0.01))
feed_forward_bias_2 = tf.Variable(tf.constant(0.0, shape=[ACTIONS_COUNT]))

input_placeholder = tf.placeholder("float", [None, INPUT_NODES])
hidden_layer = tf.nn.tanh(tf.matmul(input_placeholder, feed_forward_weights_1) + feed_forward_bias_1)
output_layer = tf.matmul(hidden_layer, feed_forward_weights_2) + feed_forward_bias_2

action_placeholder = tf.placeholder("float", [None, ACTIONS_COUNT])
target_placeholder = tf.placeholder("float", [None])

readout_action = tf.reduce_sum(tf.multiply(output_layer, action_placeholder), reduction_indices=1)

cost = tf.reduce_mean(tf.square(target_placeholder - readout_action))
train_operation = tf.train.AdamOptimizer(LEARN_RATE).minimize(cost)

observations = deque(maxlen=MEMORY_SIZE)

scores = deque(maxlen=STORE_SCORES_LEN)


# set the first action to do nothing
last_action = np.zeros(ACTIONS_COUNT)
last_action[1] = 1

probability_of_random_action = INITIAL_RANDOM_ACTION_PROB
time = 0

session.run(tf.initialize_all_variables())


def choose_next_action(state):
    new_action = np.zeros([ACTIONS_COUNT])

    if random.random() <= probability_of_random_action:
        # 액션을 무작위로 선택한다. 
        action_index = random.randrange(ACTIONS_COUNT)
    else:
        # 현재 주어진 상태를 반영해서 액션을 선택한다. 
        action_values = session.run(output_layer, feed_dict={input_placeholder: [state]})[0]
        # 가장 높은 값을 가진 액션을 실행한다. 
        action_index = np.argmax(action_values)

    new_action[action_index] = 1
    return new_action


def train():
    # 훈련할 미니배치를 샘플링한다. 
    mini_batch = random.sample(observations, MINI_BATCH_SIZE)

    # 배치변수를 가져온다. 
    previous_states = [d[OBS_LAST_STATE_INDEX] for d in mini_batch]
    actions = [d[OBS_ACTION_INDEX] for d in mini_batch]
    rewards = [d[OBS_REWARD_INDEX] for d in mini_batch]
    current_states = [d[OBS_CURRENT_STATE_INDEX] for d in mini_batch]
    agents_expected_reward = []
    
    # 에이전트에게 액션을 수행했을 때 얻을 수 있는 보상에 대한 정보를 알려준다. 
    agents_reward_per_action = session.run(output_layer, feed_dict={input_placeholder: current_states})
    for i in range(len(mini_batch)):
        if mini_batch[i][OBS_TERMINAL_INDEX]:
            # 종료를 선언하게 되므로, 더 이상 리워드를 얻을 수 없다. 
            agents_expected_reward.append(rewards[i])
        else:
            agents_expected_reward.append(
                rewards[i] + FUTURE_REWARD_DISCOUNT * np.max(agents_reward_per_action[i]))

    # 리워드를 얻게 해줄 지금 상태 내의 액션을 학습한다. 
    session.run(train_operation, feed_dict={
        input_placeholder: previous_states,
        action_placeholder: actions,
        target_placeholder: agents_expected_reward})


last_state = env.reset()
total_reward = 0

while True:
    env.render()
    last_action = choose_next_action(last_state)
    current_state, reward, terminal, info = env.step(np.argmax(last_action))
    total_reward += reward

    if terminal:
        reward = -1.
        scores.append(total_reward)

        print("Time: %s random_action_prob: %s reward %s scores differential %s" %
              (time, probability_of_random_action, total_reward,
               np.mean(scores)))
        total_reward = 0

    # 기존의 관찰에서 넘어온 것을 저장한다.
    observations.append((last_state, last_action, reward, current_state, terminal))

    # 관찰이 끝난 경우에만 트레이닝을 시작한다. 
    if len(observations) > OBSERVATION_STEPS:
        train()
        time += 1

    # 기존 값을 업데이트한다. 
    if terminal:
        last_state = env.reset()
    else:
        last_state = current_state

    # 무작위로 뽑는 액션 비율을 점진적으로 감소시킨다. 
    if probability_of_random_action > FINAL_RANDOM_ACTION_PROB \
            and len(observations) > OBSERVATION_STEPS:
        probability_of_random_action -= \
            (INITIAL_RANDOM_ACTION_PROB - FINAL_RANDOM_ACTION_PROB) / EXPLORE_STEPS
# Out:
# WARNING:tensorflow:From /Users/mac88/code/.virtualenvs/deeplearning/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:189: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Time: 0 random_action_prob: 1.0 reward 17.0 scores differential 17.0
# Time: 0 random_action_prob: 1.0 reward 18.0 scores differential 17.5
# Time: 0 random_action_prob: 1.0 reward 25.0 scores differential 20.0
# Time: 0 random_action_prob: 1.0 reward 28.0 scores differential 22.0
# Time: 0 random_action_prob: 1.0 reward 12.0 scores differential 20.0
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 19.166666666666668
# Time: 0 random_action_prob: 1.0 reward 25.0 scores differential 20.0
# Time: 0 random_action_prob: 1.0 reward 35.0 scores differential 21.875
# Time: 0 random_action_prob: 1.0 reward 40.0 scores differential 23.88888888888889
# Time: 0 random_action_prob: 1.0 reward 30.0 scores differential 24.5
# Time: 0 random_action_prob: 1.0 reward 12.0 scores differential 23.363636363636363
# Time: 0 random_action_prob: 1.0 reward 44.0 scores differential 25.083333333333332
# Time: 0 random_action_prob: 1.0 reward 9.0 scores differential 23.846153846153847
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 23.214285714285715
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 22.533333333333335
# Time: 0 random_action_prob: 1.0 reward 10.0 scores differential 21.75
# Time: 0 random_action_prob: 1.0 reward 33.0 scores differential 22.41176470588235
# Time: 0 random_action_prob: 1.0 reward 35.0 scores differential 23.11111111111111
# Time: 0 random_action_prob: 1.0 reward 17.0 scores differential 22.789473684210527
# Time: 0 random_action_prob: 1.0 reward 22.0 scores differential 22.75
# Time: 0 random_action_prob: 1.0 reward 10.0 scores differential 22.142857142857142
# Time: 0 random_action_prob: 1.0 reward 27.0 scores differential 22.363636363636363
# Time: 0 random_action_prob: 1.0 reward 10.0 scores differential 21.82608695652174
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 21.458333333333332
# Time: 0 random_action_prob: 1.0 reward 37.0 scores differential 22.08
# Time: 0 random_action_prob: 1.0 reward 17.0 scores differential 21.884615384615383
# Time: 0 random_action_prob: 1.0 reward 25.0 scores differential 22.0
# Time: 0 random_action_prob: 1.0 reward 28.0 scores differential 22.214285714285715
# Time: 0 random_action_prob: 1.0 reward 22.0 scores differential 22.20689655172414
# Time: 0 random_action_prob: 1.0 reward 18.0 scores differential 22.066666666666666
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 21.838709677419356
# Time: 0 random_action_prob: 1.0 reward 38.0 scores differential 22.34375
# Time: 0 random_action_prob: 1.0 reward 46.0 scores differential 23.060606060606062
# Time: 0 random_action_prob: 1.0 reward 28.0 scores differential 23.205882352941178
# Time: 0 random_action_prob: 1.0 reward 33.0 scores differential 23.485714285714284
# Time: 0 random_action_prob: 1.0 reward 25.0 scores differential 23.52777777777778
# Time: 0 random_action_prob: 1.0 reward 39.0 scores differential 23.945945945945947
# Time: 0 random_action_prob: 1.0 reward 21.0 scores differential 23.86842105263158
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 23.641025641025642
# Time: 0 random_action_prob: 1.0 reward 51.0 scores differential 24.325
# Time: 0 random_action_prob: 1.0 reward 20.0 scores differential 24.21951219512195
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 23.904761904761905
# Time: 0 random_action_prob: 1.0 reward 16.0 scores differential 23.72093023255814
# Time: 0 random_action_prob: 1.0 reward 64.0 scores differential 24.636363636363637
# Time: 0 random_action_prob: 1.0 reward 16.0 scores differential 24.444444444444443
# Time: 0 random_action_prob: 1.0 reward 19.0 scores differential 24.32608695652174
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 24.085106382978722
# Time: 0 random_action_prob: 1.0 reward 20.0 scores differential 24.0
# Time: 0 random_action_prob: 1.0 reward 22.0 scores differential 23.959183673469386
# Time: 0 random_action_prob: 1.0 reward 18.0 scores differential 23.84
# Time: 0 random_action_prob: 1.0 reward 29.0 scores differential 23.941176470588236
# Time: 0 random_action_prob: 1.0 reward 57.0 scores differential 24.576923076923077
# Time: 0 random_action_prob: 1.0 reward 17.0 scores differential 24.433962264150942
# Time: 0 random_action_prob: 1.0 reward 25.0 scores differential 24.444444444444443
# Time: 0 random_action_prob: 1.0 reward 24.0 scores differential 24.436363636363637
# Time: 0 random_action_prob: 1.0 reward 12.0 scores differential 24.214285714285715
# Time: 0 random_action_prob: 1.0 reward 19.0 scores differential 24.12280701754386
# Time: 0 random_action_prob: 1.0 reward 39.0 scores differential 24.379310344827587
# Time: 0 random_action_prob: 1.0 reward 19.0 scores differential 24.28813559322034
# Time: 0 random_action_prob: 1.0 reward 27.0 scores differential 24.333333333333332
# Time: 0 random_action_prob: 1.0 reward 17.0 scores differential 24.21311475409836
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 24.06451612903226
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 23.88888888888889
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 23.6875
# Time: 0 random_action_prob: 1.0 reward 14.0 scores differential 23.53846153846154
# Time: 0 random_action_prob: 1.0 reward 68.0 scores differential 24.21212121212121
# Time: 0 random_action_prob: 1.0 reward 21.0 scores differential 24.16417910447761
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 23.970588235294116
# Time: 0 random_action_prob: 1.0 reward 51.0 scores differential 24.36231884057971
# Time: 0 random_action_prob: 1.0 reward 17.0 scores differential 24.257142857142856
# Time: 0 random_action_prob: 1.0 reward 9.0 scores differential 24.04225352112676
# Time: 0 random_action_prob: 1.0 reward 36.0 scores differential 24.208333333333332
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 24.027397260273972
# Time: 0 random_action_prob: 1.0 reward 26.0 scores differential 24.054054054054053
# Time: 0 random_action_prob: 1.0 reward 12.0 scores differential 23.893333333333334
# Time: 0 random_action_prob: 1.0 reward 18.0 scores differential 23.81578947368421
# Time: 0 random_action_prob: 1.0 reward 23.0 scores differential 23.805194805194805
# Time: 0 random_action_prob: 1.0 reward 20.0 scores differential 23.756410256410255
# Time: 0 random_action_prob: 1.0 reward 9.0 scores differential 23.569620253164558
# Time: 0 random_action_prob: 1.0 reward 19.0 scores differential 23.5125
# Time: 0 random_action_prob: 1.0 reward 16.0 scores differential 23.419753086419753
# Time: 0 random_action_prob: 1.0 reward 62.0 scores differential 23.890243902439025
# Time: 0 random_action_prob: 1.0 reward 31.0 scores differential 23.97590361445783
# Time: 0 random_action_prob: 1.0 reward 20.0 scores differential 23.928571428571427
# Time: 0 random_action_prob: 1.0 reward 20.0 scores differential 23.88235294117647
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 23.75581395348837
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 23.60919540229885
# Time: 0 random_action_prob: 1.0 reward 14.0 scores differential 23.5
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 23.382022471910112
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 23.266666666666666
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 23.175824175824175
# Time: 0 random_action_prob: 1.0 reward 14.0 scores differential 23.07608695652174
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 22.989247311827956
# Time: 0 random_action_prob: 1.0 reward 20.0 scores differential 22.95744680851064
# Time: 0 random_action_prob: 1.0 reward 9.0 scores differential 22.810526315789474
# Time: 0 random_action_prob: 1.0 reward 42.0 scores differential 23.010416666666668
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 22.88659793814433
# Time: 0 random_action_prob: 1.0 reward 14.0 scores differential 22.79591836734694
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 22.696969696969695
# Time: 0 random_action_prob: 1.0 reward 59.0 scores differential 23.06
# Time: 0 random_action_prob: 1.0 reward 18.0 scores differential 23.07
# Time: 0 random_action_prob: 1.0 reward 33.0 scores differential 23.22
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 23.12
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 22.95
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 22.94
# Time: 0 random_action_prob: 1.0 reward 23.0 scores differential 23.02
# Time: 0 random_action_prob: 1.0 reward 14.0 scores differential 22.91
# Time: 0 random_action_prob: 1.0 reward 32.0 scores differential 22.88
# Time: 0 random_action_prob: 1.0 reward 10.0 scores differential 22.58
# Time: 0 random_action_prob: 1.0 reward 29.0 scores differential 22.57
# Time: 0 random_action_prob: 1.0 reward 32.0 scores differential 22.77
# Time: 0 random_action_prob: 1.0 reward 35.0 scores differential 22.68
# Time: 0 random_action_prob: 1.0 reward 28.0 scores differential 22.87
# Time: 0 random_action_prob: 1.0 reward 14.0 scores differential 22.86
# Time: 0 random_action_prob: 1.0 reward 12.0 scores differential 22.85
# Time: 0 random_action_prob: 1.0 reward 24.0 scores differential 22.99
# Time: 0 random_action_prob: 1.0 reward 14.0 scores differential 22.8
# Time: 0 random_action_prob: 1.0 reward 25.0 scores differential 22.7
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 22.64
# Time: 0 random_action_prob: 1.0 reward 20.0 scores differential 22.62
# Time: 0 random_action_prob: 1.0 reward 30.0 scores differential 22.82
# Time: 0 random_action_prob: 1.0 reward 12.0 scores differential 22.67
# Time: 0 random_action_prob: 1.0 reward 31.0 scores differential 22.88
# Time: 0 random_action_prob: 1.0 reward 12.0 scores differential 22.87
# Time: 0 random_action_prob: 1.0 reward 37.0 scores differential 22.87
# Time: 0 random_action_prob: 1.0 reward 22.0 scores differential 22.92
# Time: 0 random_action_prob: 1.0 reward 30.0 scores differential 22.97
# Time: 0 random_action_prob: 1.0 reward 49.0 scores differential 23.18
# Time: 0 random_action_prob: 1.0 reward 10.0 scores differential 23.06
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 22.99
# Time: 0 random_action_prob: 1.0 reward 16.0 scores differential 23.0
# Time: 0 random_action_prob: 1.0 reward 12.0 scores differential 22.74
# Time: 0 random_action_prob: 1.0 reward 16.0 scores differential 22.44
# Time: 0 random_action_prob: 1.0 reward 19.0 scores differential 22.35
# Time: 0 random_action_prob: 1.0 reward 68.0 scores differential 22.7
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 22.56
# Time: 0 random_action_prob: 1.0 reward 14.0 scores differential 22.31
# Time: 0 random_action_prob: 1.0 reward 23.0 scores differential 22.33
# Time: 0 random_action_prob: 1.0 reward 19.0 scores differential 22.37
# Time: 0 random_action_prob: 1.0 reward 21.0 scores differential 22.07
# Time: 0 random_action_prob: 1.0 reward 30.0 scores differential 22.17
# Time: 0 random_action_prob: 1.0 reward 19.0 scores differential 22.25
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 22.2
# Time: 0 random_action_prob: 1.0 reward 19.0 scores differential 21.75
# Time: 0 random_action_prob: 1.0 reward 26.0 scores differential 21.85
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 21.77
# Time: 0 random_action_prob: 1.0 reward 14.0 scores differential 21.78
# Time: 0 random_action_prob: 1.0 reward 16.0 scores differential 21.74
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 21.65
# Time: 0 random_action_prob: 1.0 reward 22.0 scores differential 21.69
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 21.51
# Time: 0 random_action_prob: 1.0 reward 31.0 scores differential 21.25
# Time: 0 random_action_prob: 1.0 reward 27.0 scores differential 21.35
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 21.23
# Time: 0 random_action_prob: 1.0 reward 19.0 scores differential 21.18
# Time: 0 random_action_prob: 1.0 reward 32.0 scores differential 21.38
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 21.3
# Time: 0 random_action_prob: 1.0 reward 27.0 scores differential 21.18
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 21.12
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 20.98
# Time: 0 random_action_prob: 1.0 reward 29.0 scores differential 21.1
# Time: 0 random_action_prob: 1.0 reward 29.0 scores differential 21.24
# Time: 0 random_action_prob: 1.0 reward 30.0 scores differential 21.41
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 21.45
# Time: 0 random_action_prob: 1.0 reward 21.0 scores differential 21.52
# Time: 0 random_action_prob: 1.0 reward 40.0 scores differential 21.24
# Time: 0 random_action_prob: 1.0 reward 10.0 scores differential 21.13
# Time: 0 random_action_prob: 1.0 reward 31.0 scores differential 21.33
# Time: 0 random_action_prob: 1.0 reward 10.0 scores differential 20.92
# Time: 0 random_action_prob: 1.0 reward 19.0 scores differential 20.94
# Time: 0 random_action_prob: 1.0 reward 17.0 scores differential 21.02
# Time: 0 random_action_prob: 1.0 reward 18.0 scores differential 20.84
# Time: 0 random_action_prob: 1.0 reward 16.0 scores differential 20.89
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 20.76
# Time: 0 random_action_prob: 1.0 reward 19.0 scores differential 20.83
# Time: 0 random_action_prob: 1.0 reward 21.0 scores differential 20.86
# Time: 0 random_action_prob: 1.0 reward 29.0 scores differential 20.92
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 20.85
# Time: 0 random_action_prob: 1.0 reward 19.0 scores differential 20.95
# Time: 0 random_action_prob: 1.0 reward 28.0 scores differential 21.04
# Time: 0 random_action_prob: 1.0 reward 21.0 scores differential 21.09
# Time: 0 random_action_prob: 1.0 reward 17.0 scores differential 20.64
# Time: 0 random_action_prob: 1.0 reward 16.0 scores differential 20.49
# Time: 0 random_action_prob: 1.0 reward 31.0 scores differential 20.6
# Time: 0 random_action_prob: 1.0 reward 17.0 scores differential 20.57
# Time: 0 random_action_prob: 1.0 reward 21.0 scores differential 20.65
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 20.67
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 20.68
# Time: 0 random_action_prob: 1.0 reward 12.0 scores differential 20.67
# Time: 0 random_action_prob: 1.0 reward 47.0 scores differential 21.01
# Time: 0 random_action_prob: 1.0 reward 21.0 scores differential 21.07
# Time: 0 random_action_prob: 1.0 reward 23.0 scores differential 21.16
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 21.12
# Time: 0 random_action_prob: 1.0 reward 14.0 scores differential 21.06
# Time: 0 random_action_prob: 1.0 reward 21.0 scores differential 21.18
# Time: 0 random_action_prob: 1.0 reward 20.0 scores differential 20.96
# Time: 0 random_action_prob: 1.0 reward 27.0 scores differential 21.12
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 21.13
# Time: 0 random_action_prob: 1.0 reward 16.0 scores differential 21.16
# Time: 0 random_action_prob: 1.0 reward 12.0 scores differential 20.69
# Time: 0 random_action_prob: 1.0 reward 27.0 scores differential 20.78
# Time: 0 random_action_prob: 1.0 reward 37.0 scores differential 20.82
# Time: 0 random_action_prob: 1.0 reward 25.0 scores differential 20.92
# Time: 0 random_action_prob: 1.0 reward 35.0 scores differential 21.16
# Time: 0 random_action_prob: 1.0 reward 30.0 scores differential 21.35
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 21.27
# Time: 0 random_action_prob: 1.0 reward 17.0 scores differential 21.3
# Time: 0 random_action_prob: 1.0 reward 18.0 scores differential 21.16
# Time: 0 random_action_prob: 1.0 reward 11.0 scores differential 21.17
# Time: 0 random_action_prob: 1.0 reward 18.0 scores differential 21.06
# Time: 0 random_action_prob: 1.0 reward 16.0 scores differential 20.9
# Time: 0 random_action_prob: 1.0 reward 12.0 scores differential 20.67
# Time: 0 random_action_prob: 1.0 reward 53.0 scores differential 20.92
# Time: 0 random_action_prob: 1.0 reward 14.0 scores differential 20.92
# Time: 0 random_action_prob: 1.0 reward 10.0 scores differential 20.9
# Time: 0 random_action_prob: 1.0 reward 29.0 scores differential 20.95
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 20.94
# Time: 0 random_action_prob: 1.0 reward 27.0 scores differential 20.96
# Time: 0 random_action_prob: 1.0 reward 30.0 scores differential 21.15
# Time: 0 random_action_prob: 1.0 reward 23.0 scores differential 21.18
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 21.03
# Time: 0 random_action_prob: 1.0 reward 17.0 scores differential 21.08
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 20.9
# Time: 0 random_action_prob: 1.0 reward 13.0 scores differential 20.91
# Time: 0 random_action_prob: 1.0 reward 37.0 scores differential 20.91
# Time: 0 random_action_prob: 1.0 reward 15.0 scores differential 20.84
# Time: 0 random_action_prob: 1.0 reward 40.0 scores differential 20.94
# Time: 1 random_action_prob: 0.9999333333333333 reward 17.0 scores differential 20.62
# Time: 37 random_action_prob: 0.9975333333333336 reward 36.0 scores differential 20.88
# Time: 58 random_action_prob: 0.9961333333333338 reward 21.0 scores differential 20.98
# Time: 74 random_action_prob: 0.9950666666666672 reward 16.0 scores differential 20.98
# Time: 87 random_action_prob: 0.9942000000000006 reward 13.0 scores differential 20.99
# Time: 133 random_action_prob: 0.9911333333333343 reward 46.0 scores differential 21.29
# Time: 168 random_action_prob: 0.9888000000000012 reward 35.0 scores differential 21.45
# Time: 196 random_action_prob: 0.9869333333333348 reward 28.0 scores differential 21.05
# Time: 212 random_action_prob: 0.9858666666666682 reward 16.0 scores differential 21.1
# Time: 229 random_action_prob: 0.984733333333335 reward 17.0 scores differential 21.13
# Time: 261 random_action_prob: 0.9826000000000019 reward 32.0 scores differential 21.22
# Time: 277 random_action_prob: 0.9815333333333354 reward 16.0 scores differential 21.19
# Time: 291 random_action_prob: 0.9806000000000021 reward 14.0 scores differential 21.12
# Time: 306 random_action_prob: 0.9796000000000022 reward 15.0 scores differential 20.97
# Time: 324 random_action_prob: 0.9784000000000024 reward 18.0 scores differential 20.96
# Time: 340 random_action_prob: 0.9773333333333358 reward 16.0 scores differential 21.01
# Time: 354 random_action_prob: 0.9764000000000026 reward 14.0 scores differential 20.96
# Time: 372 random_action_prob: 0.9752000000000027 reward 18.0 scores differential 20.88
# Time: 405 random_action_prob: 0.973000000000003 reward 33.0 scores differential 21.1
# Time: 423 random_action_prob: 0.9718000000000031 reward 18.0 scores differential 21.14
# Time: 432 random_action_prob: 0.9712000000000032 reward 9.0 scores differential 21.07
# Time: 443 random_action_prob: 0.9704666666666699 reward 11.0 scores differential 21.05
# Time: 471 random_action_prob: 0.9686000000000035 reward 28.0 scores differential 21.11
# Time: 490 random_action_prob: 0.9673333333333369 reward 19.0 scores differential 21.19
# Time: 508 random_action_prob: 0.9661333333333371 reward 18.0 scores differential 21.06
# Time: 520 random_action_prob: 0.9653333333333372 reward 12.0 scores differential 20.91
# Time: 535 random_action_prob: 0.9643333333333373 reward 15.0 scores differential 20.93
# Time: 549 random_action_prob: 0.963400000000004 reward 14.0 scores differential 20.88
# Time: 566 random_action_prob: 0.9622666666666708 reward 17.0 scores differential 20.73
# Time: 579 random_action_prob: 0.9614000000000043 reward 13.0 scores differential 20.75
# Time: 590 random_action_prob: 0.960666666666671 reward 11.0 scores differential 20.59
# Time: 610 random_action_prob: 0.9593333333333378 reward 20.0 scores differential 20.66
# Time: 633 random_action_prob: 0.9578000000000046 reward 23.0 scores differential 20.76
# Time: 644 random_action_prob: 0.9570666666666714 reward 11.0 scores differential 20.58
# Time: 674 random_action_prob: 0.9550666666666716 reward 30.0 scores differential 20.59
# Time: 690 random_action_prob: 0.9540000000000051 reward 16.0 scores differential 20.45
# Time: 705 random_action_prob: 0.9530000000000052 reward 15.0 scores differential 20.45
# Time: 725 random_action_prob: 0.951666666666672 reward 20.0 scores differential 20.44
# Time: 742 random_action_prob: 0.9505333333333388 reward 17.0 scores differential 20.21
# Time: 770 random_action_prob: 0.9486666666666723 reward 28.0 scores differential 20.39
# Time: 787 random_action_prob: 0.9475333333333391 reward 17.0 scores differential 20.25
# Time: 799 random_action_prob: 0.9467333333333392 reward 12.0 scores differential 20.27
# Time: 808 random_action_prob: 0.9461333333333393 reward 9.0 scores differential 20.17
# Time: 821 random_action_prob: 0.9452666666666727 reward 13.0 scores differential 20.13
# Time: 855 random_action_prob: 0.9430000000000063 reward 34.0 scores differential 20.29
# Time: 866 random_action_prob: 0.942266666666673 reward 11.0 scores differential 20.24
# Time: 884 random_action_prob: 0.9410666666666732 reward 18.0 scores differential 20.29
# Time: 910 random_action_prob: 0.93933333333334 reward 26.0 scores differential 20.36
# Time: 940 random_action_prob: 0.9373333333333402 reward 30.0 scores differential 20.45
# Time: 950 random_action_prob: 0.9366666666666736 reward 10.0 scores differential 20.26
# Time: 985 random_action_prob: 0.9343333333333406 reward 35.0 scores differential 20.48
# Time: 1023 random_action_prob: 0.9318000000000075 reward 38.0 scores differential 20.67
# Time: 1040 random_action_prob: 0.9306666666666743 reward 17.0 scores differential 20.56
# Time: 1053 random_action_prob: 0.9298000000000077 reward 13.0 scores differential 20.48
# Time: 1067 random_action_prob: 0.9288666666666745 reward 14.0 scores differential 20.45
# Time: 1083 random_action_prob: 0.927800000000008 reward 16.0 scores differential 20.45
# Time: 1110 random_action_prob: 0.9260000000000081 reward 27.0 scores differential 20.41
# Time: 1126 random_action_prob: 0.9249333333333416 reward 16.0 scores differential 20.4
# Time: 1139 random_action_prob: 0.924066666666675 reward 13.0 scores differential 20.32
# Time: 1154 random_action_prob: 0.9230666666666751 reward 15.0 scores differential 20.34
# Time: 1188 random_action_prob: 0.9208000000000087 reward 34.0 scores differential 20.53
# Time: 1199 random_action_prob: 0.9200666666666755 reward 11.0 scores differential 20.52
# Time: 1268 random_action_prob: 0.915466666666676 reward 69.0 scores differential 20.74
# Time: 1289 random_action_prob: 0.9140666666666761 reward 21.0 scores differential 20.74
# Time: 1306 random_action_prob: 0.9129333333333429 reward 17.0 scores differential 20.68
# Time: 1326 random_action_prob: 0.9116000000000097 reward 20.0 scores differential 20.77
# Time: 1367 random_action_prob: 0.9088666666666767 reward 41.0 scores differential 21.04
# Time: 1420 random_action_prob: 0.9053333333333438 reward 53.0 scores differential 21.36
# Time: 1436 random_action_prob: 0.9042666666666772 reward 16.0 scores differential 21.32
# Time: 1451 random_action_prob: 0.9032666666666773 reward 15.0 scores differential 21.2
# Time: 1470 random_action_prob: 0.9020000000000108 reward 19.0 scores differential 21.24
# Time: 1505 random_action_prob: 0.8996666666666777 reward 35.0 scores differential 21.43
# Time: 1518 random_action_prob: 0.8988000000000111 reward 13.0 scores differential 21.44
# Time: 1571 random_action_prob: 0.8952666666666782 reward 53.0 scores differential 21.7
# Time: 1588 random_action_prob: 0.894133333333345 reward 17.0 scores differential 21.5
# Time: 1621 random_action_prob: 0.8919333333333452 reward 33.0 scores differential 21.58
# Time: 1636 random_action_prob: 0.8909333333333453 reward 15.0 scores differential 21.38
# Time: 1682 random_action_prob: 0.887866666666679 reward 46.0 scores differential 21.54
# Time: 1711 random_action_prob: 0.8859333333333459 reward 29.0 scores differential 21.68
# Time: 1730 random_action_prob: 0.8846666666666794 reward 19.0 scores differential 21.7
# Time: 1770 random_action_prob: 0.882000000000013 reward 40.0 scores differential 21.92
# Time: 1791 random_action_prob: 0.8806000000000132 reward 21.0 scores differential 22.02
# Time: 1808 random_action_prob: 0.8794666666666799 reward 17.0 scores differential 22.01
# Time: 1868 random_action_prob: 0.8754666666666804 reward 60.0 scores differential 22.45
# Time: 1924 random_action_prob: 0.8717333333333475 reward 56.0 scores differential 22.89
# Time: 1958 random_action_prob: 0.869466666666681 reward 34.0 scores differential 22.7
# Time: 1978 random_action_prob: 0.8681333333333479 reward 20.0 scores differential 22.76
# Time: 1992 random_action_prob: 0.8672000000000146 reward 14.0 scores differential 22.8
# Time: 2010 random_action_prob: 0.8660000000000148 reward 18.0 scores differential 22.69
# Time: 2023 random_action_prob: 0.8651333333333482 reward 13.0 scores differential 22.69
# Time: 2050 random_action_prob: 0.8633333333333484 reward 27.0 scores differential 22.69
# Time: 2067 random_action_prob: 0.8622000000000152 reward 17.0 scores differential 22.56
# Time: 2101 random_action_prob: 0.8599333333333488 reward 34.0 scores differential 22.67
# Time: 2119 random_action_prob: 0.8587333333333489 reward 18.0 scores differential 22.7
# Time: 2178 random_action_prob: 0.854800000000016 reward 59.0 scores differential 23.12
# Time: 2234 random_action_prob: 0.8510666666666831 reward 56.0 scores differential 23.55
# Time: 2267 random_action_prob: 0.8488666666666833 reward 33.0 scores differential 23.75
# Time: 2281 random_action_prob: 0.8479333333333501 reward 14.0 scores differential 23.52
# Time: 2314 random_action_prob: 0.8457333333333503 reward 33.0 scores differential 23.7
# Time: 2337 random_action_prob: 0.8442000000000172 reward 23.0 scores differential 23.53
# Time: 2361 random_action_prob: 0.8426000000000173 reward 24.0 scores differential 23.6
# Time: 2411 random_action_prob: 0.8392666666666844 reward 50.0 scores differential 23.74
# Time: 2440 random_action_prob: 0.8373333333333512 reward 29.0 scores differential 23.82
# Time: 2465 random_action_prob: 0.8356666666666848 reward 25.0 scores differential 23.91
# Time: 2491 random_action_prob: 0.8339333333333516 reward 26.0 scores differential 24.04
# Time: 2502 random_action_prob: 0.8332000000000184 reward 11.0 scores differential 23.69
# Time: 2537 random_action_prob: 0.8308666666666853 reward 35.0 scores differential 23.69
# Time: 2664 random_action_prob: 0.8224000000000196 reward 127.0 scores differential 24.68
# Time: 2700 random_action_prob: 0.8200000000000198 reward 36.0 scores differential 24.88
# Time: 2718 random_action_prob: 0.81880000000002 reward 18.0 scores differential 24.89
# Time: 2740 random_action_prob: 0.8173333333333535 reward 22.0 scores differential 24.79
# Time: 2768 random_action_prob: 0.815466666666687 reward 28.0 scores differential 24.91
# Time: 2793 random_action_prob: 0.8138000000000205 reward 25.0 scores differential 25.02
# Time: 2844 random_action_prob: 0.8104000000000209 reward 51.0 scores differential 25.38
# Time: 2881 random_action_prob: 0.8079333333333545 reward 37.0 scores differential 25.57
# Time: 2913 random_action_prob: 0.8058000000000214 reward 32.0 scores differential 25.73
# Time: 2948 random_action_prob: 0.8034666666666883 reward 35.0 scores differential 25.94
# Time: 2973 random_action_prob: 0.8018000000000218 reward 25.0 scores differential 26.01
# Time: 3033 random_action_prob: 0.7978000000000223 reward 60.0 scores differential 26.28
# Time: 3069 random_action_prob: 0.7954000000000225 reward 36.0 scores differential 26.46
# Time: 3081 random_action_prob: 0.7946000000000226 reward 12.0 scores differential 26.49
# Time: 3138 random_action_prob: 0.790800000000023 reward 57.0 scores differential 26.95
# Time: 3275 random_action_prob: 0.7816666666666907 reward 137.0 scores differential 28.04
# Time: 3307 random_action_prob: 0.7795333333333576 reward 32.0 scores differential 28.17
# Time: 3330 random_action_prob: 0.7780000000000244 reward 23.0 scores differential 28.22
# Time: 3365 random_action_prob: 0.7756666666666914 reward 35.0 scores differential 28.45
# Time: 3426 random_action_prob: 0.7716000000000252 reward 61.0 scores differential 28.91
# Time: 3480 random_action_prob: 0.7680000000000256 reward 54.0 scores differential 29.31
# Time: 3526 random_action_prob: 0.7649333333333592 reward 46.0 scores differential 29.6
# Time: 3554 random_action_prob: 0.7630666666666928 reward 28.0 scores differential 29.75
# Time: 3599 random_action_prob: 0.7600666666666931 reward 45.0 scores differential 30.09
# Time: 3633 random_action_prob: 0.7578000000000267 reward 34.0 scores differential 30.23
# Time: 3706 random_action_prob: 0.7529333333333605 reward 73.0 scores differential 30.73
# Time: 3769 random_action_prob: 0.748733333333361 reward 63.0 scores differential 31.25
# Time: 3878 random_action_prob: 0.7414666666666951 reward 109.0 scores differential 32.04
# Time: 3938 random_action_prob: 0.7374666666666956 reward 60.0 scores differential 32.48
# Time: 3957 random_action_prob: 0.736200000000029 reward 19.0 scores differential 32.52
# Time: 3996 random_action_prob: 0.7336000000000293 reward 39.0 scores differential 32.71
# Time: 4023 random_action_prob: 0.7318000000000295 reward 27.0 scores differential 32.81
# Time: 4049 random_action_prob: 0.7300666666666964 reward 26.0 scores differential 32.79
# Time: 4067 random_action_prob: 0.7288666666666965 reward 18.0 scores differential 32.8
# Time: 4080 random_action_prob: 0.72800000000003 reward 13.0 scores differential 32.81
# Time: 4113 random_action_prob: 0.7258000000000302 reward 33.0 scores differential 33.05
# Time: 4137 random_action_prob: 0.7242000000000304 reward 24.0 scores differential 33.16
# Time: 4150 random_action_prob: 0.7233333333333638 reward 13.0 scores differential 32.95
# Time: 4168 random_action_prob: 0.7221333333333639 reward 18.0 scores differential 33.02
# Time: 4187 random_action_prob: 0.7208666666666974 reward 19.0 scores differential 33.03
# Time: 4260 random_action_prob: 0.7160000000000313 reward 73.0 scores differential 33.5
# Time: 4385 random_action_prob: 0.7076666666666989 reward 125.0 scores differential 34.45
# Time: 4438 random_action_prob: 0.7041333333333659 reward 53.0 scores differential 34.88
# Time: 4460 random_action_prob: 0.7026666666666994 reward 22.0 scores differential 34.75
# Time: 4541 random_action_prob: 0.6972666666667 reward 81.0 scores differential 35.18
# Time: 4599 random_action_prob: 0.6934000000000338 reward 58.0 scores differential 35.59
# Time: 4663 random_action_prob: 0.6891333333333676 reward 64.0 scores differential 36.1
# Time: 4703 random_action_prob: 0.6864666666667012 reward 40.0 scores differential 36.36
# Time: 4727 random_action_prob: 0.6848666666667014 reward 24.0 scores differential 36.44
# Time: 4747 random_action_prob: 0.6835333333333682 reward 20.0 scores differential 36.37
# Time: 4780 random_action_prob: 0.6813333333333684 reward 33.0 scores differential 36.54
# Time: 4791 random_action_prob: 0.6806000000000352 reward 11.0 scores differential 36.52
# Time: 4851 random_action_prob: 0.6766000000000356 reward 60.0 scores differential 36.97
# Time: 4962 random_action_prob: 0.6692000000000364 reward 111.0 scores differential 37.74
# Time: 5086 random_action_prob: 0.6609333333333707 reward 124.0 scores differential 38.87
# Time: 5218 random_action_prob: 0.6521333333333716 reward 132.0 scores differential 39.5
# Time: 5260 random_action_prob: 0.649333333333372 reward 42.0 scores differential 39.71
# Time: 5302 random_action_prob: 0.6465333333333723 reward 42.0 scores differential 39.96
# Time: 5428 random_action_prob: 0.6381333333333732 reward 126.0 scores differential 41.02
# Time: 5476 random_action_prob: 0.6349333333333735 reward 48.0 scores differential 41.09
# Time: 5501 random_action_prob: 0.6332666666667071 reward 25.0 scores differential 40.81
# Time: 5535 random_action_prob: 0.6310000000000406 reward 34.0 scores differential 40.99
# Time: 5576 random_action_prob: 0.6282666666667076 reward 41.0 scores differential 41.25
# Time: 5678 random_action_prob: 0.6214666666667084 reward 102.0 scores differential 42.08
# Time: 5744 random_action_prob: 0.6170666666667088 reward 66.0 scores differential 42.39
# Time: 5867 random_action_prob: 0.6088666666667097 reward 123.0 scores differential 43.49
# Time: 5894 random_action_prob: 0.6070666666667099 reward 27.0 scores differential 43.23
# Time: 5959 random_action_prob: 0.6027333333333771 reward 65.0 scores differential 43.71
# Time: 6013 random_action_prob: 0.5991333333333775 reward 54.0 scores differential 43.92
# Time: 6046 random_action_prob: 0.5969333333333777 reward 33.0 scores differential 44.1
# Time: 6058 random_action_prob: 0.5961333333333778 reward 12.0 scores differential 43.76
# Time: 6191 random_action_prob: 0.5872666666667121 reward 133.0 scores differential 44.8
# Time: 6237 random_action_prob: 0.5842000000000458 reward 46.0 scores differential 45.07
# Time: 6294 random_action_prob: 0.5804000000000462 reward 57.0 scores differential 45.24
# Time: 6333 random_action_prob: 0.5778000000000465 reward 39.0 scores differential 45.42
# Time: 6503 random_action_prob: 0.5664666666667144 reward 170.0 scores differential 46.95
# Time: 6588 random_action_prob: 0.5608000000000484 reward 85.0 scores differential 47.2
# Time: 6649 random_action_prob: 0.5567333333333822 reward 61.0 scores differential 47.25
# Time: 6809 random_action_prob: 0.5460666666667167 reward 160.0 scores differential 48.51
# Time: 6850 random_action_prob: 0.5433333333333836 reward 41.0 scores differential 48.72
# Time: 7019 random_action_prob: 0.5320666666667182 reward 169.0 scores differential 50.27
# Time: 7154 random_action_prob: 0.5230666666667192 reward 135.0 scores differential 51.44
# Time: 7189 random_action_prob: 0.5207333333333861 reward 35.0 scores differential 51.66
# Time: 7317 random_action_prob: 0.5122000000000537 reward 128.0 scores differential 52.67
# Time: 7459 random_action_prob: 0.5027333333333881 reward 142.0 scores differential 53.92
# Time: 7659 random_action_prob: 0.48940000000005623 reward 200.0 scores differential 55.58
# Time: 7859 random_action_prob: 0.47606666666672437 reward 200.0 scores differential 57.4
# Time: 8059 random_action_prob: 0.4627333333333925 reward 200.0 scores differential 58.81
# Time: 8244 random_action_prob: 0.45040000000006053 reward 185.0 scores differential 60.1
# Time: 8361 random_action_prob: 0.4426000000000614 reward 117.0 scores differential 60.94
# Time: 8557 random_action_prob: 0.42953333333339616 reward 196.0 scores differential 62.76
# Time: 8757 random_action_prob: 0.4162000000000643 reward 200.0 scores differential 64.43
# Time: 8863 random_action_prob: 0.4091333333333984 reward 106.0 scores differential 65.26
# Time: 9063 random_action_prob: 0.39580000000006654 reward 200.0 scores differential 67.02
# Time: 9245 random_action_prob: 0.38366666666673455 reward 182.0 scores differential 68.34
# Time: 9344 random_action_prob: 0.3770666666667353 reward 99.0 scores differential 69.04
# Time: 9544 random_action_prob: 0.3637333333334034 reward 200.0 scores differential 70.79
# Time: 9744 random_action_prob: 0.35040000000007154 reward 200.0 scores differential 72.53
# Time: 9818 random_action_prob: 0.34546666666673875 reward 74.0 scores differential 73.16
# Time: 10018 random_action_prob: 0.3321333333334069 reward 200.0 scores differential 74.81
# Time: 10209 random_action_prob: 0.31940000000007496 reward 191.0 scores differential 75.45
# Time: 10409 random_action_prob: 0.3060666666667431 reward 200.0 scores differential 77.09
# Time: 10609 random_action_prob: 0.2927333333334112 reward 200.0 scores differential 78.91
# Time: 10809 random_action_prob: 0.27940000000007936 reward 200.0 scores differential 80.69
# Time: 11009 random_action_prob: 0.2660666666667475 reward 200.0 scores differential 82.41
# Time: 11209 random_action_prob: 0.25273333333341563 reward 200.0 scores differential 84.16
# Time: 11409 random_action_prob: 0.23940000000008377 reward 200.0 scores differential 85.65
# Time: 11609 random_action_prob: 0.2260666666667519 reward 200.0 scores differential 87.28
# Time: 11789 random_action_prob: 0.21406666666675322 reward 180.0 scores differential 88.76
# Time: 11989 random_action_prob: 0.20073333333342136 reward 200.0 scores differential 90.41
# Time: 12189 random_action_prob: 0.1874000000000895 reward 200.0 scores differential 92.16
# Time: 12389 random_action_prob: 0.17406666666675763 reward 200.0 scores differential 93.56
# Time: 12589 random_action_prob: 0.16073333333342577 reward 200.0 scores differential 95.2
# Time: 12789 random_action_prob: 0.1474000000000939 reward 200.0 scores differential 97.08
# Time: 12989 random_action_prob: 0.13406666666676204 reward 200.0 scores differential 98.51
# Time: 13189 random_action_prob: 0.12073333333342928 reward 200.0 scores differential 99.14
# Time: 13389 random_action_prob: 0.10740000000009464 reward 200.0 scores differential 100.82
# Time: 13589 random_action_prob: 0.09406666666676 reward 200.0 scores differential 102.59
# Time: 13789 random_action_prob: 0.08073333333342536 reward 200.0 scores differential 104.24
# Time: 13989 random_action_prob: 0.06740000000009072 reward 200.0 scores differential 105.63
# Time: 14189 random_action_prob: 0.05406666666675696 reward 200.0 scores differential 107.09
# Time: 14389 random_action_prob: 0.04073333333342371 reward 200.0 scores differential 108.63
# Time: 14589 random_action_prob: 0.027400000000090456 reward 200.0 scores differential 110.35
# Time: 14789 random_action_prob: 0.014066666666757204 reward 200.0 scores differential 111.9
# Time: 14989 random_action_prob: 0.00073333333342393 reward 200.0 scores differential 113.56
# Time: 15189 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 114.83
# Time: 15389 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 116.2
# Time: 15589 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 117.11
# Time: 15789 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 118.51
# Time: 15989 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 120.32
# Time: 16189 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 121.93
# Time: 16389 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 123.66
# Time: 16589 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 125.4
# Time: 16789 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 127.22
# Time: 16989 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 129.09
# Time: 17189 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 130.76
# Time: 17389 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 132.52
# Time: 17589 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 134.39
# Time: 17789 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 136.21
# Time: 17989 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 138.02
# Time: 18189 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 139.29
# Time: 18389 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 140.04
# Time: 18589 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 141.51
# Time: 18789 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 143.29
# Time: 18989 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 144.48
# Time: 19189 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 145.9
# Time: 19389 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 147.26
# Time: 19589 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 148.86
# Time: 19789 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 150.62
# Time: 19989 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 152.42
# Time: 20189 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 154.09
# Time: 20389 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 155.98
# Time: 20589 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 157.38
# Time: 20789 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 158.27
# Time: 20989 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 159.03
# Time: 21189 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 159.71
# Time: 21389 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 161.29
# Time: 21589 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 162.87
# Time: 21789 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 163.61
# Time: 21989 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 165.13
# Time: 22189 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 166.88
# Time: 22389 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 168.54
# Time: 22589 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 170.13
# Time: 22789 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 171.11
# Time: 22989 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 172.45
# Time: 23189 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 173.22
# Time: 23389 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 174.95
# Time: 23589 random_action_prob: -6.66666665760702e-05 reward 200.0 scores differential 176.3
